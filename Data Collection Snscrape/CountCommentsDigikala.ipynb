# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('ShortPersianEmo.xlsx', header=None, names=['tweet','label'])
df2 = pd.read_excel('Digikala_Fa.xlsx')

# %%
df1.head()
# Out:
#                                                                               tweet  \
# 0                                  شما کرونا بگیر، سلامتی داشتنم در کنارش ادامه بده
# 1                                        سبک \nروی لب زیبا\nخوشرنگ برای سفید پوستان
# 2  می‌گویند چند دقیقه قبل زلزله شهر کابل را خوب تکان داده اند . #StopHazaraGenocide
# 3                                        تا اطلاع ثانوی قطار کشتی هواپیما سوار نشین
# 4                          اینجا زمانی خیابانی بود در شهر سولیدار دونباس اوکراین …
#
#    label
# 0  OTHER
# 1  HAPPY
# 2  HAPPY
# 3   FEAR
# 4  OTHER

# %%
df2 = df2.rename(columns={'text': 'tweet'})

# %%
df2.head()
# Out:
#                                                                                                                                                                                                                                                                                    tweet  \
# 0                                                                                                                                                                       این اولین تجربه من برای خرید آیفون هست امروز به دستم رسیده به اسم طلایی هست ولی دراصل رزگلده خیلی هم خوش‌رنگ هست
# 1                                                                                                                                                                                                                                                         خرید این محصول را توصیه می‌کنم
# ...

# %%
common_rows = pd.merge(df1['tweet'].str[:20], df2['tweet'].str[:20], how='inner')

# %%
common_rows.shape
# Out:
# (4, 1)

# %%
df2.shape
# Out:
# (1079, 7)

# %%
df1.shape
# Out:
# (5472, 2)
