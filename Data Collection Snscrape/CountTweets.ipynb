# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('ShortPersianEmo.xlsx', header=None, names=['tweet','label'])
df2 = pd.read_excel('snscrape_gaz.xlsx', header=None, names=['no','index','tweet'])

# %%
df1.head()
# Out:
#                                                                               tweet  \
# 0                                  شما کرونا بگیر، سلامتی داشتنم در کنارش ادامه بده
# 1                                        سبک \nروی لب زیبا\nخوشرنگ برای سفید پوستان
# 2  می‌گویند چند دقیقه قبل زلزله شهر کابل را خوب تکان داده اند . #StopHazaraGenocide
# 3                                        تا اطلاع ثانوی قطار کشتی هواپیما سوار نشین
# 4                          اینجا زمانی خیابانی بود در شهر سولیدار دونباس اوکراین …
#
#    label
# 0  OTHER
# 1  HAPPY
# 2  HAPPY
# 3   FEAR
# 4  OTHER

# %%
df2.head()
# Out:
#    no  index  \
# 0   0    311
# 1   1    349
# 2   2    295
# 3   3    108
# 4   4    244
#
#                                                                                       tweet
# 0                         همچین میگه قول‌ میدم سال بعد گاز قطع نمیشه که انگار سال بعدم هست.
# 1  کپسول های گاز رو که با خودش برد رو ننوشتی وگرنه الان گاز قطع نمیشد که... #زن_زندگی_آزادی
# 2     من یه نسخی خاصی دارم. گاهی دوست دارم باسن پارتنرمو گاز بگیرم. الانم شدید نیاز دارم :|
# 3                احسنت آفرین حرف حق👌🏻 سال بعد اصلا نیستین دیگه که بخاین قطع گاز داشته باشیم
# 4                            راهکار دولت برای برف، کمبود گاز ، آلودگی هوا ، ....تعطیل است .

# %%
common_rows = pd.merge(df1[['tweet']], df2[['tweet']], how='inner')

# %%
common_rows.head()
# Out:
#                                                                                               tweet
# 0   گاز صرفه جویی کن ولی ملیارد ملیارد چمدون کن بده خرس نصرالله و اسد گردن دراز و یمن و فلسطین عراق
# 1                                             کسی هم که دستور داد گاز ذخیره نشه حتما بابای من بوده
# 2                                 زندگی بی گاز، با دود، با تورم جریان داره گروه مثبت اندیشان بیچاره
# 3                 نمیتونم کنار کسی غذا بخورم واقعا مدل خوردن گاز زدن و صدا در اوردنشون میره رو مخم.
# 4                                     #تبريزـ صف گاز سی‌ان‌جی بیشتر از سه کیلومتر #گاز #زمستان_سخت

# %%
common_rows.shape
# Out:
# (118, 1)

# %%
df2.shape
# Out:
# (394, 3)

# %%
df1.shape
# Out:
# (5472, 2)
