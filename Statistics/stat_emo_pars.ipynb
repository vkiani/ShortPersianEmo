# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
em_ds = pd.read_excel("drive/MyDrive/Rasooli/EmoPars/EmoPars_Fa_Cleaned.xlsx");

em_ds.head()
# Out:
#                                                 text  Anger  Fear  Happiness  \
# 0  کرونا رو شکست میدهیم؟ مرحله بعد چه گوهی میخوای...      1     1          0
# 1  اگر در چند ماه اخیر تصمیم داشته اید وارد بورس ...      0     1          0
# 2  یکی از پدرسوختگی های برانداز اینه که ظاهرا ژست...      1     1          0
# 3                              یکی از دوستای دبستانم      0     0          0
# 4  اینقدر گرفتار مسایل میشی که تخصص از دستت درد م...      0     0          0
#
#    Hatred  Sadness  Wonder
# 0       1        1       1
# 1       0        1       0
# 2       1        1       0
# 3       0        0       0
# 4       0        0       1

# %%
em_ds['length'] = em_ds['text'].str.len()

em_ds.head()
# Out:
#                                                 text  Anger  Fear  Happiness  \
# 0  کرونا رو شکست میدهیم؟ مرحله بعد چه گوهی میخوای...      1     1          0
# 1  اگر در چند ماه اخیر تصمیم داشته اید وارد بورس ...      0     1          0
# 2  یکی از پدرسوختگی های برانداز اینه که ظاهرا ژست...      1     1          0
# 3                              یکی از دوستای دبستانم      0     0          0
# 4  اینقدر گرفتار مسایل میشی که تخصص از دستت درد م...      0     0          0
#
#    Hatred  Sadness  Wonder  length
# 0       1        1       1      54
# 1       0        1       0     269
# 2       1        1       0     271
# 3       0        0       0      21
# 4       0        0       1      85

# %%
cnt = dict(em_ds[['Anger', 'Fear', 'Happiness', 'Hatred', 'Sadness', 'Wonder']].sum())
print(cnt)
# Out:
# {'Anger': 1632, 'Fear': 690, 'Happiness': 692, 'Hatred': 1256, 'Sadness': 1770, 'Wonder': 986}

# %%
cnt.values()
# Out:
# dict_values([1632, 690, 692, 1256, 1770, 986])

# %%
courses = cnt.keys()
values = cnt.values()

fig = plt.figure(figsize = (10, 5))

plt.bar(courses, values, color ='#3498db', width = 0.4)
plt.ylabel("No. of sample for each class in test data")
plt.show()

# %%
cc = pd.DataFrame(cnt.items())

# %%
labels = list(cnt.keys())
sizes = list(cnt.values())
colors = ['#3fba36', '#66b3ff','#ffcc99','#ff9999', '#d44444']
fig1, ax1 = plt.subplots()
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{v:d}'.format(p=pct,v=val)
    return my_autopct
ax1.pie(sizes, labels=labels, colors=colors, autopct=make_autopct(sizes), startangle=50)
centre_circle = plt.Circle((0,0), 0.70 ,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax1.axis('equal')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize = (15, 5))

plt.hist(em_ds['length'], bins=100)
# Out:
# (array([  9.,   5.,   4.,  12.,  26.,  36., 158., 542., 698., 663., 478.,
#         732., 719., 668., 734., 510., 709., 688., 686., 667., 639., 425.,
#         634., 585., 565., 562., 364., 524., 531., 453., 409., 294., 404.,
#         413., 435., 399., 251., 373., 378., 414., 477., 770., 515., 592.,
#         334., 238., 247., 149., 232., 223., 235., 201., 135., 198., 196.,
#         193., 148., 119., 162., 156., 136., 149., 162.,  98., 148., 171.,
#         141., 156., 113., 142., 127., 149., 134., 110., 146., 142., 113.,
#         141.,  77., 134., 118., 131., 140., 136.,  91., 140., 141., 143.,
#         172., 123., 162., 192., 176., 205., 147., 268., 371., 482., 495.,
#         159.]),
#  array([  1.  ,   3.81,   6.62,   9.43,  12.24,  15.05,  17.86,  20.67,
#          23.48,  26.29,  29.1 ,  31.91,  34.72,  37.53,  40.34,  43.15,
#          45.96,  48.77,  51.58,  54.39,  57.2 ,  60.01,  62.82,  65.63,
#          68.44,  71.25,  74.06,  76.87,  79.68,  82.49,  85.3 ,  88.11,
# ...

# %%
np.min(em_ds['length'])
# Out:
# 1

# %%
np.max(em_ds['length'])
# Out:
# 282

# %%
np.mean(em_ds['length'])
# Out:
# 113.06573990732407

# %%
em_ds.shape
# Out:
# (29997, 8)
