# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
em_ds = pd.read_excel("drive/MyDrive/ShortPersianEmo 2023 Code/Data/ShortPersianEmo/ShortPersianEmo.xlsx", header=None);

em_ds.head()
# Out:
#                                                    0      1
# 0   شما کرونا بگیر، سلامتی داشتنم در کنارش ادامه بده  OTHER
# 1         سبک \nروی لب زیبا\nخوشرنگ برای سفید پوستان  HAPPY
# 2  می‌گویند چند دقیقه قبل زلزله شهر کابل را خوب ت...  HAPPY
# 3         تا اطلاع ثانوی قطار کشتی هواپیما سوار نشین   FEAR
# 4  اینجا زمانی خیابانی بود در شهر سولیدار دونباس ...  OTHER

# %%
em_ds[2] = em_ds[0].str.len()

em_ds.head()
# Out:
#                                                    0      1   2
# 0   شما کرونا بگیر، سلامتی داشتنم در کنارش ادامه بده  OTHER  48
# 1         سبک \nروی لب زیبا\nخوشرنگ برای سفید پوستان  HAPPY  40
# 2  می‌گویند چند دقیقه قبل زلزله شهر کابل را خوب ت...  HAPPY  80
# 3         تا اطلاع ثانوی قطار کشتی هواپیما سوار نشین   FEAR  42
# 4  اینجا زمانی خیابانی بود در شهر سولیدار دونباس ...  OTHER  56

# %%
from collections import Counter
cnt = Counter(em_ds[1])
cnt = dict(cnt)
print(cnt)
# Out:
# {'OTHER': 1403, 'HAPPY': 1625, 'FEAR': 380, 'SAD': 939, 'ANGRY': 1125}

# %%
cnt.values()
# Out:
# dict_values([1403, 1625, 380, 939, 1125])

# %%
courses = cnt.keys()
values = cnt.values()

fig = plt.figure(figsize = (10, 5))

plt.bar(courses, values, color ='#3498db', width = 0.4)
plt.ylabel("No. of sample for each class in test data")
plt.show()

# %%
cc = pd.DataFrame(cnt.items())

# %%
labels = list(cnt.keys())
sizes = list(cnt.values())
colors = ['#3fba36', '#66b3ff','#ffcc99','#ff9999', '#d44444']
fig1, ax1 = plt.subplots()
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{v:d}'.format(p=pct,v=val)
    return my_autopct
ax1.pie(sizes, labels=labels, colors=colors, autopct=make_autopct(sizes), startangle=50)
centre_circle = plt.Circle((0,0), 0.70 ,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax1.axis('equal')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize = (20, 5))

plt.hist(em_ds[2], bins=70)
# Out:
# (array([132., 144., 141., 117., 146., 138., 133., 170., 168., 146., 132.,
#         136., 133., 145., 157., 129., 147., 176., 130.,  63.,  47.,  54.,
#          67.,  58.,  58.,  65.,  57.,  44.,  44.,  42.,  60.,  61.,  59.,
#          59.,   0.,  50.,  79.,  60.,  64.,  56.,  61.,  60.,  65.,  65.,
#          56.,  50.,  51.,  60.,  58.,  54.,  59.,  68.,  57.,  61.,  55.,
#          50.,  53.,  55.,  47.,  50.,  46.,  53.,  43.,  46.,  44.,  42.,
#          53.,  52.,  48.,  43.]),
#  array([31.        , 31.97142857, 32.94285714, 33.91428571, 34.88571429,
#         35.85714286, 36.82857143, 37.8       , 38.77142857, 39.74285714,
#         40.71428571, 41.68571429, 42.65714286, 43.62857143, 44.6       ,
#         45.57142857, 46.54285714, 47.51428571, 48.48571429, 49.45714286,
#         50.42857143, 51.4       , 52.37142857, 53.34285714, 54.31428571,
#         55.28571429, 56.25714286, 57.22857143, 58.2       , 59.17142857,
# ...

# %%
np.min(em_ds[2])
# Out:
# 31

# %%
np.max(em_ds[2])
# Out:
# 99

# %%
np.mean(em_ds[2])
# Out:
# 56.99305555555556

# %%
em_ds.shape
# Out:
# (5472, 3)

# %%
counts, bins, _ = plt.hist(em_ds[2], bins = 69)

counts
# Out:
# array([132., 144., 141., 117., 146., 138., 133., 170., 168., 146., 132.,
#        136., 133., 145., 157., 129., 147., 176., 130.,  63.,  47.,  54.,
#         67.,  58.,  58.,  65.,  57.,  44.,  44.,  42.,  60.,  61.,  59.,
#         59.,  50.,  79.,  60.,  64.,  56.,  61.,  60.,  65.,  65.,  56.,
#         50.,  51.,  60.,  58.,  54.,  59.,  68.,  57.,  61.,  55.,  50.,
#         53.,  55.,  47.,  50.,  46.,  53.,  43.,  46.,  44.,  42.,  53.,
#         52.,  48.,  43.])
