# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
em_ds = pd.read_csv("drive/MyDrive/Rasooli/BERT_Models/PersianTweets/persian_tweets_single.csv");

em_ds.head()
# Out:
#                                                 text     label
# 0   بهت حق میدم زیرا کینه و خشمی که جنایات #رئیسی...       SAD
# 1  #احمد_الحسن_فرستاده_امام_مهدی :\nنفس انسان از ...  SURPRISE
# 2  نمیدانم که ای بی خرد را چی شده؟! بخدا که حیران...  SURPRISE
# 3  درو بر #زاکانی ستاره درخشان #مناظره. همون اولی...       SAD
# 4  مرد قوی با آدم رجز خوانی درگیر شد بعد از کتک م...       SAD

# %%
em_ds['length'] = em_ds['text'].str.len()

em_ds.head()
# Out:
#                                                 text     label  length
# 0   بهت حق میدم زیرا کینه و خشمی که جنایات #رئیسی...       SAD     179
# 1  #احمد_الحسن_فرستاده_امام_مهدی :\nنفس انسان از ...  SURPRISE     260
# 2  نمیدانم که ای بی خرد را چی شده؟! بخدا که حیران...  SURPRISE     101
# 3  درو بر #زاکانی ستاره درخشان #مناظره. همون اولی...       SAD     279
# 4  مرد قوی با آدم رجز خوانی درگیر شد بعد از کتک م...       SAD     229

# %%
from collections import Counter
cnt = Counter(em_ds['label'])
cnt = dict(cnt)
print(cnt)
# Out:
# {'SAD': 34328, 'SURPRISE': 12859, 'ANGRY': 20069, 'HAPPY': 28024, 'FEAR': 17624, 'HATE': 925}

# %%
cnt.values()
# Out:
# dict_values([34328, 12859, 20069, 28024, 17624, 925])

# %%
courses = cnt.keys()
values = cnt.values()

fig = plt.figure(figsize = (10, 5))

plt.bar(courses, values, color ='#3498db', width = 0.4)
plt.ylabel("No. of sample for each class in test data")
plt.show()

# %%
cc = pd.DataFrame(cnt.items())

# %%
labels = list(cnt.keys())
sizes = list(cnt.values())
colors = ['#3fba36', '#66b3ff','#ffcc99','#ff9999', '#d44444','#ffcc99']
fig1, ax1 = plt.subplots()
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{v:d}'.format(p=pct,v=val)
    return my_autopct
ax1.pie(sizes, labels=labels, colors=colors, autopct=make_autopct(sizes), startangle=50)
centre_circle = plt.Circle((0,0), 0.70 ,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax1.axis('equal')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize = (15, 5))

plt.hist(em_ds['length'], bins=100)
# Out:
# (array([3.000e+00, 7.000e+00, 6.000e+00, 1.900e+01, 6.100e+01, 9.400e+01,
#         1.220e+02, 1.840e+02, 2.310e+02, 3.770e+02, 3.930e+02, 5.400e+02,
#         5.680e+02, 8.350e+02, 7.500e+02, 7.940e+02, 8.740e+02, 9.320e+02,
#         1.482e+03, 1.089e+03, 1.232e+03, 1.299e+03, 1.966e+03, 1.605e+03,
#         1.576e+03, 1.519e+03, 1.604e+03, 2.096e+03, 1.495e+03, 1.538e+03,
#         1.454e+03, 1.949e+03, 1.484e+03, 1.496e+03, 1.477e+03, 1.519e+03,
#         2.109e+03, 1.372e+03, 1.447e+03, 1.425e+03, 1.982e+03, 1.463e+03,
#         1.353e+03, 1.467e+03, 1.365e+03, 1.785e+03, 1.390e+03, 1.323e+03,
#         1.280e+03, 1.259e+03, 1.675e+03, 1.236e+03, 1.230e+03, 1.230e+03,
#         1.639e+03, 1.153e+03, 1.130e+03, 1.124e+03, 1.098e+03, 1.503e+03,
#         1.113e+03, 1.151e+03, 1.093e+03, 1.418e+03, 1.062e+03, 1.008e+03,
#         9.970e+02, 1.093e+03, 1.403e+03, 1.040e+03, 1.035e+03, 1.007e+03,
#         1.409e+03, 1.030e+03, 1.033e+03, 1.065e+03, 1.087e+03, 1.610e+03,
#         1.297e+03, 1.234e+03, 1.398e+03, 2.072e+03, 1.772e+03, 2.613e+03,
#         4.383e+03, 2.786e+03, 5.770e+02, 4.790e+02, 5.760e+02, 6.780e+02,
#         1.151e+03, 1.579e+03, 1.700e+03, 2.500e+01, 6.000e+00, 1.200e+01,
#         1.300e+01, 1.500e+01, 2.100e+01, 8.000e+01]),
#  array([  6.  ,   9.22,  12.44,  15.66,  18.88,  22.1 ,  25.32,  28.54,
#          31.76,  34.98,  38.2 ,  41.42,  44.64,  47.86,  51.08,  54.3 ,
#          57.52,  60.74,  63.96,  67.18,  70.4 ,  73.62,  76.84,  80.06,
#          83.28,  86.5 ,  89.72,  92.94,  96.16,  99.38, 102.6 , 105.82,
#         109.04, 112.26, 115.48, 118.7 , 121.92, 125.14, 128.36, 131.58,
#         134.8 , 138.02, 141.24, 144.46, 147.68, 150.9 , 154.12, 157.34,
#         160.56, 163.78, 167.  , 170.22, 173.44, 176.66, 179.88, 183.1 ,
#         186.32, 189.54, 192.76, 195.98, 199.2 , 202.42, 205.64, 208.86,
#         212.08, 215.3 , 218.52, 221.74, 224.96, 228.18, 231.4 , 234.62,
#         237.84, 241.06, 244.28, 247.5 , 250.72, 253.94, 257.16, 260.38,
#         263.6 , 266.82, 270.04, 273.26, 276.48, 279.7 , 282.92, 286.14,
#         289.36, 292.58, 295.8 , 299.02, 302.24, 305.46, 308.68, 311.9 ,
#         315.12, 318.34, 321.56, 324.78, 328.  ]),
#  <BarContainer object of 100 artists>)

# %%
np.min(em_ds['length'])
# Out:
# 6

# %%
np.max(em_ds['length'])
# Out:
# 328

# %%
np.mean(em_ds['length'])
# Out:
# 174.81306169780987

# %%
em_ds.shape
# Out:
# (113829, 3)
